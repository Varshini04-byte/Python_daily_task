# %%
#Hierarchical inheritance
#Task1:
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
class Student(Person):
    def __init__(self,name,age,marks):
        super().__init__(name,age)
        self.marks=marks
    def show(self):
        print(f"Student name:{self.name}")
        print(f"Student age:{self.age}")
        print(f"Student marks:{self.marks}")
class Teacher(Person):
    def __init__(self,name,age,subject):
        super().__init__(name,age)
        self.subject=subject
    def show(self):
        print(f"Teacher name:{self.name}")
        print(f"Teacher age:{self.age}")
        print(f"Teacher subject:{self.subject}")
obj1=Student("varsh",22,90)
obj2=Teacher("varsh",40,"math")
obj1.show()
obj2.show()
# Out:
# Student name:varsh
# Student age:22
# Student marks:90
# Teacher name:varsh
# Teacher age:40
# Teacher subject:math

# %% [markdown]
# 2. Animal → Dog, Cat
# Question
# Define class Animal with method eat(). Create subclasses Dog and Cat.
# Concept
# • Method inheritance.
# How to Solve
# 1. Create parent class Animal.
# 2. Write method eat().
# 3. Create child classes Dog and Cat.
# 4. Create objects.
# 5. Call eat() using both objects.

# %%
#Hierarchical inheritance
#Task2:
class Animal:
    def eat(self):
        print(" animal is eating")
class Dog(Animal):
    def eat(self):
        print("Dog is eating chicken")
class Cat(Animal):
    def eat(self):
        print("Cat is eating curd")
#object:
d=Dog()
c=Cat()
#Calling inheritance
d.eat()
c.eat()
# Out:
# Dog is eating chicken
# Cat is eating curd

# %% [markdown]
# 3. Vehicle → Car, Bike
# Question
# Create class Vehicle with method start(). Create subclasses Car and Bike.
# Concept
# • One parent method shared by multiple children.
# How to Solve
# 1. Create Vehicle.
# 2. Add start().
# 3. Inherit it in Car.
# 4. Inherit it in Bike.
# 5. Call start() from both child objects.

# %%
#Hierarchical inheritance
#Task2:
class Vehicle:
    def start(self):
        print(" Vehicle is starting")
class Car(Vehicle):
    def start(self):
        print("Car is starting with disel")
class Bike(Vehicle):
    def start(self):
        print("Bike is starting with petrol")
#object:
c=Car()
b=Bike()
#Calling inheritance
c.start()
b.start()
# Out:
# Car is starting with disel
# Bike is starting with petrol

# %% [markdown]
# 4. Shape → Circle, Rectangle
# Question
# Define class Shape with method area(). Create subclasses Circle and Rectangle.
# Concept
# • Parent provides common method.
# • Children may later override it.
# How to Solve
# 1. Create Shape.
# 2. Add area().
# 3. Create Circle.
# 4. Create Rectangle.
# 5. Call area().

# %%
#Hierarchical inheritance
#Task4:
class Shape:
    def area(self):
        pass
class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        print("Area of circle:", 3.14*self.radius*self.radius)
class Rectangle(Shape):
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        print("Area of rectangle:",self.length*self.width)
#object:
c=Circle(5)
r=Rectangle(5,5)
#Calling inheritance
c.area()
r.area()
# Out:
# Area of circle: 78.5
# Area of rectangle: 25

# %% [markdown]
# 5. Employee → Manager, Developer
# Question
# Create class Employee with attributes emp_id and salary. Create subclasses Manager and
# Developer.
# Concept
# • Attribute inheritance.
# How to Solve
# 1. Create parent constructor.
# 2. Store emp_id and salary.
# 3. Create two child classes.
# 4. Show inherited attributes.

# %%
#Hierarchical inheritance
#Task5:
class Employee:
    def __init__(self,emp_id,salary):
        self.emp_id=emp_id
        self.salary=salary
class Manager(Employee):
    def display(self):
        print(f"Manager emp_id:{self.emp_id}")
        print(f"Manager salary:{self.salary}")

class Developer(Employee):
    def display(self):
        print(f"Developer emp_id:{self.emp_id}")
        print(f"Developer salary:{self.salary}")
        
#object:
m=Manager(1234,50000)
d=Developer(3456,60000)
#Calling inheritance
m.display()
d.display()
# Out:
# Manager emp_id:1234
# Manager salary:50000
# Developer emp_id:3456
# Developer salary:60000

# %% [markdown]
# 6. BankAccount → SavingsAccount, CurrentAccount
# Question
# Define class BankAccount with method deposit().
# Concept
# • Common banking functionality.
# How to Solve
# 1. Create deposit().
# 2. Create two child classes.
# 3. Call deposit() from both.

# %%
#Hierarchical inheritance
#Task6:
class BankAccount:
    def __init__(self,balance):
        self.balance = balance
    def deposit(self,amt):
        self.balance += amt
class SavingsAccount(BankAccount):
    def deposit(self,amt):
        self.balance+=amt
        print(f"SavingsAccount:{self.balance}")
class CurrentAccount(BankAccount):
    def deposit(self,amt):
        self.balance+=amt
        print(f"CurrentAccount:{self.balance}")

#object:
s=SavingsAccount(50000)
c=CurrentAccount(60000)
#Calling inheritance
s.deposit(2000)
c.deposit(3000)
# Out:
# SavingsAccount:52000
# CurrentAccount:63000

# %% [markdown]
# 7. Device → Mobile, Laptop
# Question
# Create class Device with method turn_on().
# Concept
# • Reusing common functionality.
# How to Solve
# 1. Create parent.
# 2. Add turn_on().
# 3. Create two children.
# 4. Demonstrate inheritance.

# %%
#Hierarchical inheritance
#Task7:
class Device:
    def turn_on(self):
        print("Device turn on")
class Mobile(Device):
    def turn_on(self):
        print("Mobile is turn on")
class Laptop(Device):
    def turn_on(self):
        print("Laptop is turn on")

#object:
m=Mobile()
l=Laptop()
#Calling inheritance
m.turn_on()
l.turn_on()
# Out:
# Mobile is turn on
# Laptop is turn on

# %% [markdown]
# 8. Sports → Cricket, Football
# Question
# Define class Sports with method play().
# Concept
# • Common method inherited.
# How to Solve
# 1. Parent class.
# 2. Common method.
# 3. Two subclasses.
# 4. Call inherited method.

# %%
#Hierarchical inheritance
#Task8:
class Sports:
    def play(self):
        print("playing sports")
class Cricket(Sports):
    def play(self):
        print("playing Cricket")
class Football(Device):
    def play(self):
        print("playing Football")

#object:
c=Cricket()
f=Football()
#Calling inheritance
c.play()
f.play()
# Out:
# playing Cricket
# playing Football

# %% [markdown]
# 9. Product → Electronics, Clothing
# Question
# Create class Product with attribute price.
# Concept
# • Common data shared by children.
# How to Solve
# 1. Create constructor.
# 2. Store price.
# 3. Create child classes.
# 4. Display price.

# %%
#Task9:
class Product:
    def __init__(self,price):
        self.price = price
class Electronics(Product):
    def __init__(self,price):
        super().__init__(price)
    def display(self):
        print("Electronics Price:",self.price)
class Clothing(Product):
    def __init__(self,price):
        super().__init__(price)
    def display(self):
        print("Clothing Price:",self.price)

#object:
e=Electronics(50000)
c=Clothing(60000)
#Calling inheritance
e.display()
c.display()
# Out:
# Electronics Price: 50000
# Clothing Price: 60000

# %% [markdown]
# 10. Book → Fiction, NonFiction
# Question
# Define class Book with attributes title and author.
# Concept
# • Constructor inheritance.
# How to Solve
# 1. Parent constructor.
# 2. Two child classes.
# 3. Access inherited attributes.

# %%
#Task9:
class Book:
    def __init__(self,title,author):
        self.title = title
        self.author=author
class Fiction(Book):
    def __init__(self,title,author):
        super().__init__(title,author)
    def display(self):
        print("Fiction Book title:",self.title)
        print("Fiction Book author:",self.author)
class NonFiction(Book):
    def __init__(self,title,author):
        super().__init__(title,author)
    def display(self):
        print("NonFiction Book title:",self.title)
        print("NonFiction Book author:",self.author)

#object:
a=Fiction("The Alchemist","Paulo Coelho")
b=NonFiction("Atomic Habits","James Clear")
#Calling inheritance
a.display()
b.display()
# Out:
# Fiction Book title: The Alchemist
# Fiction Book author: Paulo Coelho
# NonFiction Book title: Atomic Habits
# NonFiction Book author: James Clear

# %% [markdown]
# 11. Account → UserAccount, AdminAccount
# Question
# Define class Account with method show_balance().
# Concept
# • Shared functionality.
# How to Solve
# 1. Create method.
# 2. Inherit into both children.
# 3. Call method.

# %%
#Hierarchical inheritance
#Task11:
class Account:
    def __init__(self,balance):
        self.balance = balance
    def show_balance(self):
        print(f"Show Account balance:{self.balance}")
class UserAccount(Account):
    def show_balance(self):
        print(f"Show UserAccount balance:{self.balance}")
    
class AdminAccount(Account):
    def show_balance(self):
        print(f"Show AdminAccount balance:{self.balance}")

#object:
s=UserAccount(50000)
c=AdminAccount(60000)
#Calling inheritance
s.show_balance()
c.show_balance()
# Out:
# Show UserAccount balance:50000
# Show AdminAccount balance:60000

# %% [markdown]
# 12. Transport → Bus, Train
# Question
# Define class Transport with method move().
# Concept
# • One behavior for many children.
# How to Solve
# 1. Parent class.
# 2. Add method.
# 3. Create Bus.
# 4. Create Train.
# 5. Demonstrate inheritance.

# %%
#Hierarchical inheritance
#Task12:
class Transport:
    def move(self):
        print("moving Transport")
class Bus(Transport):
    def move(self):
        print("Bus is moving")
    
class Train(Transport):
    def move(self):
        print("Train is moving")

#object:
b=Bus()
t=Train()
#Calling inheritance
b.move()
t.move()
# Out:
# Bus is moving
# Train is moving

# %% [markdown]
# 13. Person Constructor
# Concept
# Using super() to call the parent constructor.
# How to Solve
# 1. Create constructor in parent.
# 2. Create child constructors.
# 3. Use super().__init__().
# 4. Add child-specific attribute.
# 5. Display all data.

# %%
#Hierarchical inheritance
#Task13:
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
class Student(Person):
    def __init__(self,name,age,marks):
        super().__init__(name,age)
        self.marks=marks
    def show(self):
        print(f"Student name:{self.name}")
        print(f"Student age:{self.age}")
        print(f"Student marks:{self.marks}")

obj1=Student("varsh",22,90)

obj1.show()
# Out:
# Student name:varsh
# Student age:22
# Student marks:90

# %% [markdown]
# 14. Animal Sound Override
# Concept
# Method Overriding.
# How to Solve
# 1. Parent has sound().
# 2. Dog overrides.
# 3. Cat overrides.
# 4. Call method from each object.

# %%
#Hierarchical inheritance
#Task14:
class Animal:
    def __init__(self,name):
        self.name=name
    def sound(self):
        print(" animal makes sound")
class Dog(Animal):
    def __init__(self,name):
        super().__init__(name)
    def sound(self):
        print("Bhauuuuu")
class Cat(Animal):
    def __init__(self,name):
        super().__init__(name)
    def sound(self):
        print("Meowwww")
#object:
d=Dog("Puppy")
c=Cat("Kitty")
#Calling inheritance
d.sound()
c.sound()
# Out:
# Bhauuuuu
# Meowwww

# %% [markdown]
# 15. Vehicle Constructor
# Concept
# Constructor inheritance.
# How to Solve
# 1. Parent stores brand.
# 2. Car adds doors.
# 3. Bike adds engine_cc.
# 4. Use super().

# %%
#Hierarchical inheritance
#Task2:
class Vehicle:
    def __init__(self,brand):
        self.brand=brand
class Car(Vehicle):
    def __init__(self,brand,doors):
        super().__init__(brand)
        self.doors=doors
    def display(self):
        print(f"Car brand:{self.brand}")
        print(f"Car doors:{self.doors}")
class Bike(Vehicle):
     def __init__(self,brand,engine_cc):
        super().__init__(brand)
        self.engine_cc=engine_cc
     def display(self):
        print(f"Bike brand:{self.brand}")
        print(f"Bike engine_cc:{self.engine_cc}")
         
#object:
c=Car("toyoto",4)
b=Bike("pulser",120)
#Calling inheritance
c.display()
b.display()
# Out:
# Car brand:toyoto
# Car doors:4
# Bike brand:pulser
# Bike engine_cc:120

# %% [markdown]
# 17. Employee Details
# Concept
# Method Extension.
# How to Solve
# 1. Parent has get_details().
# 2. Child calls parent method.
# 3. Add child information.
# 4. Display complete details.

# %%
#Hierarchical inheritance
#Task17:
class Employee:
    def __init__(self,emp_id,salary):
        self.emp_id=emp_id
        self.salary=salary
    def get_details(self):
        return self.emp_id
    def get_details(self):
        return self.salary
class Manager(Employee):
    def __init__(self,emp_id,salary,teamsize):
        super().__init__(emp_id,salary)
        self.teamsize=teamsize
    def get_details(self):
        return self.teamsize
    def display(self):
        print(f"Manager emp_id:{self.emp_id}")
        print(f"Manager salary:{self.salary}")
        print(f"Manager teamsize:{self.teamsize}")


#object:
m=Manager(1234,50000,5)
#Calling inheritance
m.display()
# Out:
# Manager emp_id:1234
# Manager salary:50000
# Manager teamsize:5

# %% [markdown]
# 18. BankAccount Interest
# Concept
# Different child behavior.
# How to Solve
# 1. Parent constructor.
# 2. Savings has one interest.
# 3. Current has another.
# 4. Calculate separately.

# %%
#Hierarchical inheritance
#Task18:
class BankAccount:
    def __init__(self,balance):
        self.balance = balance
class Savings(BankAccount):
    def __init__(self,balance):
         super().__init__(balance)
    def interest(self):
        amt=self.balance+(self.balance*5/100)
        print(f"Savings:{self.balance}")
        print(f"Balance after interst:",amt)
class Current(BankAccount):
    def __init__(self,balance):
         super().__init__(balance)
    def interest(self):
        amt=self.balance+(self.balance*2/100)
        print(f"Current:{self.balance}")
        print(f"Balance after interst:",amt)

#object:
s=Savings(50000)
c=Current(60000)
#Calling inheritance
s.interest()
c.interest()
# Out:
# Savings:50000
# Balance after interst: 52500.0
# Current:60000
# Balance after interst: 61200.0

# %% [markdown]
# 19. Device Info
# Concept
# Method overriding.
# How to Solve
# 1. Parent method info().
# 2. Phone overrides.
# 3. Tablet overrides.

# %%
#Task19:
class Device:
    def info(self):
        print("It is a Device")
class Phone:
    def info(self):
        print("It is a phone")
class Tablet:
    def info(self):
        print("It is a tablet")
a=Phone()
b=Tablet()
a.info()
b.info()
# Out:
# It is a phone
# It is a tablet

# %% [markdown]
# 20. Game Start
# Concept
# Inheritance + Additional Methods.
# How to Solve
# 1. Parent method start().
# 2. Chess inherits.
# 3. Chess adds checkmate().
# 4. Ludo adds roll_dice().

# %%
#Task20:
class GameStart:
    def start(self):
        print("Game is started")
class Chess(GameStart):
    def Checkmate(self):
        print("Checkmate")
class Ludo(GameStart):
    def roll_dice(self):
        print("dice rolled")
c=Chess()
l=Ludo()
c.start()
c.Checkmate()
l.start()
l.roll_dice()
# Out:
# Game is started
# Checkmate
# Game is started
# dice rolled

# %% [markdown]
# 21. Private Attribute
# Concept
# Encapsulation + Inheritance.
# How to Solve
# 1. Parent has private attribute.
# 2. Create getter.
# 3. Child uses getter.
# 4. Display value.

# %%
#Task21:
class Person:
    def __init__(self,name):
        self.name=name
class Student(Person):
    def __init__(self,name):
        super().__init__(name)
    def display(self):
        print(f"Student name:{self.name}")
class Teacher(Person):
    def __init__(self,name):
        super().__init__(name)
    def display(self):
        print(f"Teacher name:{self.name}")
obj1=Student("varshini")
obj2=Teacher("jyothi")
obj1.display()
obj2.display()
# Out:
# Student name:varshini
# Teacher name:jyothi

# %% [markdown]
# 22. Method Overriding
# Concept
# Both children implement their own version.
# How to Solve
# 1. Parent method.
# 2. Child 1 overrides.
# 3. Child 2 overrides.
# 4. Call method using different objects.

# %%
#Task22:
class Animal:
    def eat(self):
        print("Animal is eating")
class Dog(Animal):
    def eat(self):
        print("Dog is eating")
class lion(Animal):
    def eat(self):
        print("lion is eating")
a=Dog()
b=lion()
a.eat()
b.eat()
# Out:
# Dog is eating
# lion is eating

# %% [markdown]
# 23. School Management
# Concept
# Real-world hierarchical inheritance.
# How to Solve
# 1. Parent → Person
# 2. Common attributes (name, age)
# 3. Student → marks
# 4. Teacher → subject
# 5. Staff → department
# 6. Display information.

# %%
#Task23
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age

class Student(Person):
    def __init__(self,name,age,marks):
        super().__init__(name,age)
        self.marks=marks
    def display(self):
        print(f"Student name:{self.name}")
        print(f"Student age:{self.age}")
        print(f"Student marks:{self.marks}")
class Teacher(Person):
    def __init__(self,name,age,subject):
        super().__init__(name,age)
        self.subject=subject
    def display(self):
        print(f"teacher name:{self.name}")
        print(f"teacher age:{self.age}")
        print(f"teacher subject:{self.subject}")
class Staff(Person):
    def __init__(self,name,age,dept):
        super().__init__(name,age)
        self.dept=dept
    def display(self):
        print(f"Staff name:{self.name}")
        print(f"Staff age:{self.age}")
        print(f"Staff dept:{self.dept}")

s=Student("varshini",20,90)
t=Teacher("swathi",45,"Python")
f=Staff("Padma",60,"Administative")
s.display()
t.display()
f.display()
# Out:
# Student name:varshini
# Student age:20
# Student marks:90
# teacher name:swathi
# teacher age:45
# teacher subject:Python
# Staff name:Padma
# Staff age:60
# Staff dept:Administative

# %% [markdown]
# 24. Bank System
# Concept
# Three children inherit one parent.
# How to Solve
# 1. Parent → Account
# 2. Store balance.
# 3. Savings → interest.
# 4. Current → overdraft.
# 5. FixedDeposit → maturity.
# 6. Show each separately.

# %%
#Hierarchical inheritance
#Task24:
class Account:
    def __init__(self,balance):
        self.balance = balance
class Savings(Account):
    def __init__(self,balance,interest):
        super().__init__(balance)
        self.interest=interest
    def display(self):
        print(f"Savings:{self.balance}")
        print(f" interst:{self.interest}")
class Current(Account):
    def __init__(self,balance,overdraft):
        super().__init__(balance)
        self.overdraft=overdraft
    def display(self):
        print(f"Current:{self.balance}")
        print(f"Overdraft:{self.overdraft}")
class FixedDeposite(Account):
    def __init__(self,balance,maturity):
        super().__init__(balance)
        self.maturity=maturity
    def display(self):
        print(f"Current:{self.balance}")
        print(f"maturity:{self.maturity}")

#object:
s=Savings(50000,6)
c=Current(60000,1000)
f=FixedDeposite(10000,5)
#Calling inheritance
s.display()
c.display()
f.display()
# Out:
# Savings:50000
#  interst:6
# Current:60000
# Overdraft:1000
# Current:10000
# maturity:5

# %% [markdown]
# 25. Vehicle System
# Concept
# Common parent with specialized children.
# How to Solve
# 1. Parent → Vehicle
# 2. TwoWheeler adds helmet method.
# 3. FourWheeler adds seatbelt method.
# 4. Demonstrate both.

# %%
#Task25
class Vehicle:
    def __init__(self, brand):
        self.brand = brand

    def start(self):
        print(f"{self.brand} vehicle is starting.")
class TwoWheeler(Vehicle):
    def helmet(self):
        print("Helmet is mandatory for two-wheelers.")
class FourWheeler(Vehicle):
    def seatbelt(self):
        print("Seatbelt is mandatory for four-wheelers.")
bike = TwoWheeler("pulser")
bike.start()
bike.helmet()
car = FourWheeler("Hyundai")
car.start()
car.seatbelt()
# Out:
# pulser vehicle is starting.
# Helmet is mandatory for two-wheelers.
# Hyundai vehicle is starting.
# Seatbelt is mandatory for four-wheelers.

# %% [markdown]
# 26. Animal System
# Concept
# Method overriding.
# How to Solve
# 1. Parent method eat().
# 2. Herbivore overrides.
# 3. Carnivore overrides.
# 4. Show different outputs.

# %%
#Task26
class Animal:
    def eat(self):
        print("Animal eats food")
class Herbivore(Animal):
    def eat(self):
        print("Herbivore eats plants")
class Carnivore(Animal):
    def eat(self):
        print("Carnivore eats meat")
h = Herbivore()
c = Carnivore()
h.eat()
c.eat()
# Out:
# Herbivore eats plants
# Carnivore eats meat

# %% [markdown]
# 27. Employee Salary
# Concept
# Different salary calculations.
# How to Solve
# 1. Parent stores common data.
# 2. FullTime calculates monthly salary.
# 3. PartTime calculates hourly salary.
# 4. Override calculation method.

# %%
#Task27
class Employee:
    def __init__(self, name):
        self.name = name
    def calculate_salary(self):
        print("Salary calculation")
class FullTime(Employee):
    def __init__(self, name, monthly_salary):
        super().__init__(name)
        self.monthly_salary = monthly_salary
    def calculate_salary(self):
        print("Employee:", self.name)
        print("Monthly Salary:", self.monthly_salary)
class PartTime(Employee):
    def __init__(self, name, hours, hourly_rate):
        super().__init__(name)
        self.hours = hours
        self.hourly_rate = hourly_rate
    def calculate_salary(self):
        salary = self.hours * self.hourly_rate
        print("Employee:", self.name)
        print("Hourly Salary:", salary)
f = FullTime("varsh", 80000)
p = PartTime("sam", 60, 400)
f.calculate_salary()
p.calculate_salary()
# Out:
# Employee: varsh
# Monthly Salary: 80000
# Employee: sam
# Hourly Salary: 24000

# %% [markdown]
# 28. Shape Hierarchy
# Concept
# One parent with multiple children.
# How to Solve
# 1. Parent → Shape
# 2. Child → 2DShape
# 3. Child → 3DShape
# 4. Each has its own methods.
# 5. Show both inherit from Shape.

# %%
#Task28
class Shape:
    def display(self):
        print("This is a shape")
class twoD(Shape):
    def area(self):
        print("Calculating area")
class threeD(Shape):
    def volume(self):
        print("Calculating volume ")
TWOd = twoD()
THREEd = threeD()
TWOd.display()
TWOd.area()
THREEd.display()
THREEd.volume()
# Out:
# This is a shape
# Calculating area
# This is a shape
# Calculating volume

# %% [markdown]
# 29. Notification System
# Concept
# Method overriding.
# How to Solve
# 1. Parent → Notification
# 2. Method send()
# 3. Email overrides.
# 4. SMS overrides.
# 5. Push overrides.
# 6. Call send() using each object.

# %%
#Task29
class Notification:
    def send(self):
        print("Sending notification")
class Email(Notification):
    def send(self):
        print("Sending Email")
class SMS(Notification):
    def send(self):
        print("Sending SMS")
class Push(Notification):
    def send(self):
        print("Sending Push Notification")
email = Email()
sms = SMS()
push = Push()
email.send()
sms.send()
push.send()
# Out:
# Sending Email
# Sending SMS
# Sending Push Notification

# %% [markdown]
# 30. Your Own Hierarchical Design
# Concept
# Complete hierarchical inheritance program.
# How to Solve
# 1. Choose one parent class.
# 2. Add common attributes.
# 3. Add common methods.
# 4. Create three child classes.
# 5. Add child-specific methods.
# 6. Create objects of all child classes.
# 7. Show that every child can:
# o Access parent attributes.
# o Access parent methods.
# o Use its own methods independently.

# %%
#Task30
class Vehicle:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color
    def start(self):
        print(self.brand, "vehicle is started")
class Car(Vehicle):
    def open_trunk(self):
        print("Car trunk is opened")
class Bike(Vehicle):
    def wear_helmet(self):
        print("Wear helmet")
class Bus(Vehicle):
    def open_door(self):
        print("Bus door is opened")
c = Car("Toyota", "black")
b = Bike("pulser", "Black")
bu = Bus("delux", "green")
print("Brand:", c.brand)
print("Color:", c.color)
c.start()
c.open_trunk()
print("Brand:", b.brand)
print("Color:", b.color)
b.start()
b.wear_helmet()
print("Brand:", bu.brand)
print("Color:", bu.color)
bu.start()
bu.open_door()
# Out:
# Brand: Toyota
# Color: black
# Toyota vehicle is started
# Car trunk is opened
# Brand: pulser
# Color: Black
# pulser vehicle is started
# Wear helmet
# Brand: delux
# Color: green
# delux vehicle is started
# Bus door is opened
