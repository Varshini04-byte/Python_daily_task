# %%
#Encapsulation:
#Task2:
class Student:
    def __init__(self,marks):
        self.__marks=marks
    def get_marks(self):
        return self.__marks
    def set_marks(self,marks):
        if marks>0:
            if marks>=0 and marks<=100:
                self.__marks=marks
        else:
            print("Accept marks only between 0 and 100")
A1=Student(90)
print(A1.get_marks())
A1.set_marks(-99)
print(A1.get_marks())
# Out:
# 90
# Accept marks only between 0 and 100
# 90

# %%
#Encapsulation:
#Task1:
class BankAccount:
    def __init__(self,balance):
        self.__balance=balance
    def get_balance(self):
        return self.__balance
    def deposite_set_balance(self,amount):
        if amount>0:
            self.__balance+=amount
            return self.__balance
        else:
            print("Amount must be greater than 0")
    def withdrawal_set_balance(self,amount):
         if amount>0:
             self.__balance-=amount
             return self.__balance
         else:
             print("Insufficient amount")
B1=BankAccount(5000)
print(B1.get_balance())
B1.deposite_set_balance(1000)
B1.withdrawal_set_balance(500)
print(B1.get_balance())
# Out:
# 5000
# 5500

# %%
#Encapsulation:
#Task3:
class Employee:
    def __init__(self,salary):
        self.__salary=salary
    def get_salary(self):
        return self.__salary
    def set_salary(self,new_salary):
        minimum_salary=self.__salary*0.9
        if new_salary>=minimum_salary:
            self.__salary=new_salary
            print("salary updated")
        else:
            print("Rejected")
Emp=Employee(50000)
print(Emp.get_salary())
Emp.set_salary(45000)
print(Emp.get_salary())
# Out:
# 50000
# salary updated
# 45000

# %%
#Encapsulation:
#Task4:
class Mobile:
    def __init__(self,price):
        self.__price=price
    def get_price(self):
        return self.__price
    def set_price(self,price):
        if price>0:
            self.__price=price
        else:
            print("Invalid price")
M1=Mobile(50000)
print(Emp.get_salary())
Emp.set_salary(60000)
print(Emp.get_salary())
# Out:
# 60000
# salary updated
# 60000

# %%
#Encapsulation:
#Task4:
class Person:
    def __init__(self,age):
        self.__age=age
    def get_age(self):
        return self.__age
    def set_age(self,age):
        if age>=0 and age<=120:
            self.__age=age
        else:
            print("Invalid age")
A1=Person(50)
print(A1.get_age())
A1.set_age(80)
print(A1.get_age())
# Out:
# 50
# 80

# %%
#Encapsulation:
#Task6:
class Product:
    def __init__(self,price,stock):
        self.__price=price
        self.__stock=stock
    def get_price(self):
        return self.__price
    def get_stock(self):
        return self.__stock
    def update_price(self,price):
        if price>0:
            self.__price=price
        else:
            print("Invalid price")
    def update_stock(self,stock):
        if stock>0:
            self.__stock=stock
        else:
            print("Invalid stock")
P1=Product(20,30)
print(P1.get_price())
print(P1.get_stock())

P1.update_price(80)
P1.update_stock(8)

print(P1.get_price())
print(P1.get_stock())
# Out:
# 20
# 30
# 80
# 8

# %%
#Encapsulation:
#Task7:
from datetime import datetime
class Car:
    def __init__(self,name,model,year):
        self.name=name
        self.__model=model
        self.__year=year
    def get_model(self):
        return self.__model
    def get_year(self):
        return self.__year
    def set_model(self,model):
            self.__model=model
    def set_year(self,year):
        current_year=datetime.now().year
        if year<=2026:
            self.__year=year
        else:
            print("Year cannot be greater than current year")
C1=Car("Thar","i20",2026)
print(C1.get_model())
print(C1.get_year())
C1.set_model("Breeza")
C1.set_year(2024)

print(C1.get_model())
print(C1.get_year())
# Out:
# i20
# 2026
# Breeza
# 2024

# %%
#Encapsulation:
#Task8:
#from datetime import datetime
class User:
    def __init__(self,name,password):
        self.name=name
        self.__password=password
    def get_password(self):
        return self.__password
    def change_password(self,password):
        if len(password)>=8:
            self.__password=password
        else:
            print("Invalid password")
U1=User("sam","1234")
U1.change_password("6789101234")

print(U1.get_password())
# Out:
# 6789101234

# %%
#Encapsulation:
#Task9:
class Rectangle:
    def __init__(self,length,width):
        self.__length=length
        self.__width=width
    def get_length(self):
        return self.__length
    def get_width(self):
        return self.__width
    def set_length(self,length):
        if length>0:
            self.__length=length
        else:
            print("Invalid length")
    def set_width(self,width):
        if width>0:
            self.__width=width
        else:
            print("Invalid width")
    def area(self):
        return self.__length*self.__width
R1=Rectangle(2,3)
print(R1.get_length())
print(R1.get_width())
print(R1.area())
R1.set_length(3)
R1.set_width(5)
print(R1.get_length())
print(R1.get_width())
print(R1.area())
# Out:
# 2
# 3
# 6
# 3
# 5
# 15

# %%
#Encapsulation:
#Task10:
class Account:
    history=[]
    def __init__(self,balance):
        self.__balance=balance
    def get_balance(self):
        return self.__balance
    def deposite(self,amount):
        if amount>0:
            self.__balance+=amount
            Account.history.append(self.__balance)
        else:
            print("Invalid deposite ")
    def withdraw(self,amount):
        if amount>0 and amount<=self.__balance:
            self.__balance-=amount
            Account.history.append(self.__balance)
        else:
            print("Insufficient balance")
A1=Account(10000)
print(A1.get_balance())
A1.deposite(5000)
A1.withdraw(3000)
print(A1.get_balance())
print("history:",Account.history)
# Out:
# 10000
# 12000
# history: [15000, 12000]

# %%
#Encapsulation:
#Task11:
class Temperature:
    def __init__(self,celsius):
        self.__celsius=celsius
    def get_celsius(self):
        return self.__celsius
    def set_celsius(self,celsius):
        self.__celsius=celsius
    def to_fahrenheit(self):
        fahrenheit=(self.__celsius*9/5)+32
        print(fahrenheit)
        
T1=Temperature(10)
print(T1.get_celsius())
T1.set_celsius(50)
T1.to_fahrenheit()
print(T1.get_celsius())
#print("history:",Account.history)
# Out:
# 10
# 122.0
# 50

# %%
#Encapsulation:
#Task12:
class Book:
    def __init__(self,price):
        self.__price=price
    def get_price(self):
        return self.__price
    def set_price(self,price):
        if price>500:
            self.__price=price-(price*10/100)
        else:
            self.__price=price
   
b1=Book(200)
print(b1.get_price())
b1.set_price(600)
print(b1.get_price())
# Out:
# 200
# 540.0

# %%
#Encapsulation:
#Task13:
class Player:
    def __init__(self,score):
        self.__score=score
    def get_score(self):
        return self.__score
    def set_score(self,score):
        if score>0:
            self.__score=score
        else:
            print("Score is negative")
   
p1=Player(20)
print(p1.get_score())
p1.set_score(100)
print(p1.get_score())
# Out:
# 20
# 100

# %%
#Encapsulation:
#Task14:
class Laptop:
    def __init__(self,ram,storage):
        self.__ram=ram
        self.__storage=storage
    def get_ram(self):
        return self.__ram
    def get_storage(self):
        return self.__storage
    def set_ram(self,ram):
        if ram>0:
            self.__ram=ram
        else:
            print("ram should not be negative")
    def set_storage(self,storage):
        if storage>0:
            self.__storage=storage
        else:
            print("storage should not be negative")
   
L1=Laptop(6,120)
print(L1.get_ram())
print(L1.get_storage())
L1.set_ram(8)
L1.set_storage(120)
print(L1.get_ram())
print(L1.get_storage())
# Out:
# 6
# 120
# 8
# 120

# %%
#Encapsulation:
#Task15:
class Employee:
    def __init__(self,id,salary):
        self.__id=id
        self.__salary=salary
    def get_id(self):
        return self.__id
    def get_salary(self):
        return self.__salary
Emp=Employee(123,50000)
print(Emp.get_id())
print(Emp.get_salary())
# Out:
# 123
# 50000

# %%
#Abstraction:
#Task16:
from abc import ABC, abstractmethod 
class Shape(ABC) :
        
    @abstractmethod
    def calculate_area(self):
        pass
    @abstractmethod
    def calculate_perimeter(self):
        pass
class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def calculate_area(self):
        return 3.14*self.radius*self.radius
           
    def calculate_perimeter(self):
        return 2*3.14*self.radius
class Rectangle(Shape):
    def __init__(self,length,breadth):
        self.length=length
        self.breadth=breadth
    
    def calculate_area(self):
        return self.length*self.breadth
            
    def calculate_perimeter(self):
        return 2*(self.length+self.breadth)
c=Circle(5)
print("Circle area:",c.calculate_area())
print("Circle perimeter:",c.calculate_perimeter())
r=Rectangle(10,5)
print("rectangle area:",r.calculate_area())
print("rectangle perimeter:",r.calculate_perimeter())
# Out:
# Circle area: 78.5
# Circle perimeter: 31.400000000000002
# rectangle area: 50
# rectangle perimeter: 30

# %%
#Abstraction:
#Task17:
from abc import ABC, abstractmethod 
class Vechicle(ABC) :
   @abstractmethod
    def start(self):
        pass
   @abstractmethod
    def stop(self):
        pass
#Car class
class Car(Vechicle):
    def start(self):
        print("Car starts with a key")
    def stop(self):
        print("Car stops with a brake")
 #Bike class       
class Bike(Vechicle):
    def start(self):
        print("bike starts with kick")
    def stop(self):
        print("bike stops with brakes")
car=Car()
car.start()
car.stop()
bike=Bike()
bike.start()
bike.stop()
# Out:
#   Cell In[112], line 6
#     def start(self):
#     ^
# IndentationError: unexpected indent

# %%
#Abstraction:
#Task17:
from abc import ABC, abstractmethod 
class Vehicle(ABC) :
    
    @abstractmethod
    def start(self):
        pass
    @abstractmethod
    def stop(self):
        pass
#Car class
class Car(Vehicle):
    def start(self):
        print("Car starts with a key")
    def stop(self):
        print("Car stops with a brake")
 #Bike class       
class Bike(Vehicle):
    def start(self):
        print("bike starts with kick")
    def stop(self):
        print("bike stops with brakes")
car=Car()
car.start()
car.stop()
bike=Bike()
bike.start()
bike.stop()
# Out:
# Car starts with a key
# Car stops with a brake
# bike starts with kick
# bike stops with brakes

# %%
#Abstraction:
#Task18:
from abc import ABC, abstractmethod 
class Payment(ABC) :
   @abstractmethod
   def process_payment(self,amount):
        pass
# class1
class CreditCardPayment(Payment):
    def process_payment(self,amount):
        print("processing credit card payement:{amount}")
 #class2       
class UPIPayment(Payment):
    def process_payment(self,amount):
        print("processing UPI payement:{amount}")
credit=CreditCardPayment()
credit.process_payment(5000)
upi=UPIPayment()
upi.process_payment(1500)
# Out:
# processing credit card payement:{amount}
# processing UPI payement:{amount}

# %%
#Abstraction:
#Task18:
from abc import ABC, abstractmethod

# Abstract class
class Animal(ABC):

    @abstractmethod
    def make_sound(self):
        pass


# Dog subclass
class Dog(Animal):

    def make_sound(self):
        return "Bark"


# Cat subclass
class Cat(Animal):

    def make_sound(self):
        return "Meow"


# Objects
dog = Dog()
cat = Cat()

# Output
print(dog.make_sound())
print(cat.make_sound())
# Out:
# Bark
# Meow

# %%
#Abstraction:
#Task20:
from abc import ABC, abstractmethod

# Abstract class
class Report(ABC):

    @abstractmethod
    def generate_report(self):
        pass


# subclass
class PDFReport(Report):

    def generate_report(self):
        print("PDF report generated")


#  subclass
class ExcelReport(Report):

    def generate_report(self):
        print("ExcelReport is generated")


# Objects
p=PDFReport()
e=ExcelReport()
print(p.generate_report())
print(e.generate_report())
# Out:
# PDF report generated
# None
# ExcelReport is generated
# None

# %%
#Abstraction:
#Task21:
from abc import ABC, abstractmethod

# Abstract class
class BankAccount(ABC):

    @abstractmethod
    def calculate_interest(self):
        pass


# subclass
class SavingsAccount(BankAccount):

    def __init__(self,balance):
        self.balance=balance
    def calculate_interest(self):
        return self.balance*0.05
#  subclass
class CurrentAccount(BankAccount):
    def __init__(self,balance):
        self.balance=balance
    def calculate_interest(self):
        return self.balance*0.02


# Objects
savings=SavingsAccount(1000)
current=CurrentAccount(1000)
print("Savings Interest:", savings.calculate_interest())
print("Current Interest:", current.calculate_interest())
# Out:
# Savings Interest: 50.0
# Current Interest: 20.0

# %%
# Abstract class
#Task22:
from abc import ABC, abstractmethod
class Device(ABC):

    @abstractmethod
    def turn_on(self):
        pass
    def turn_off(self):
        pass
# subclass
class TV(Device):
    def turn_on(self):
        print("TV is turned on")
    def turn_off(self):
        print("TV is turned off")
class Laptop(Device):
    def turn_on(self):
        print("Laptop is turned on")
    def turn_off(self):
        print("Laptop is turned off")
class Fan(Device):
    def turn_on(self):
        print("Fan is turned on")
    def turn_off(self):
        print("Fan is turned off")
    
    

# Objects
t=TV()
t.turn_on()
t.turn_off()
L=Laptop()
L.turn_on()
L.turn_off()
f=Fan()
f.turn_on()
f.turn_off()
# Out:
# TV is turned on
# TV is turned off
# Laptop is turned on
# Laptop is turned off
# Fan is turned on
# Fan is turned off

# %%
# Abstract class
#Task23:

from abc import ABC, abstractmethod

# Abstract class
class Calculator(ABC):

    @abstractmethod
    def compute(self, a, b):
        pass
class AddCalculator(Calculator):

    def compute(self, a, b):
        return a + b
class MultiplyCalculator(Calculator):

    def compute(self, a, b):
        return a * b
add = AddCalculator()
multiply = MultiplyCalculator()
print("Addition:", add.compute(10, 5))
print("Multiplication:", multiply.compute(10, 5))
# Out:
# Addition: 15
# Multiplication: 50

# %%
#Abstraction
#Task24:
from abc import ABC, abstractmethod

# Abstract class
class Employee(ABC):

    @abstractmethod
    def calculate_bonus(self):
        pass
class Manager(Employee):

    def __init__(self, salary):
        self.salary = salary

    def calculate_bonus(self):
        return self.salary * 0.20   # 20% bonus
class Developer(Employee):

    def __init__(self, salary):
        self.salary = salary

    def calculate_bonus(self):
        return self.salary * 0.15   # 15% bonus
class HR(Employee):

    def __init__(self, salary):
        self.salary = salary

    def calculate_bonus(self):
        return self.salary * 0.10   # 10% bonus


# Objects
manager = Manager(50000)
developer = Developer(50000)
hr = HR(50000)

# Output
print("Manager Bonus:", manager.calculate_bonus())
print("Developer Bonus:", developer.calculate_bonus())
print("HR Bonus:", hr.calculate_bonus())
# Out:
# Manager Bonus: 10000.0
# Developer Bonus: 7500.0
# HR Bonus: 5000.0

# %%
#Abstraction
#Task25:
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape3D(ABC):

    @abstractmethod
    def volume(self):
        pass

    @abstractmethod
    def surface_area(self):
        pass


# Cube subclass
class Cube(Shape3D):

    def __init__(self, side):
        self.side = side

    def volume(self):
        return self.side ** 3

    def surface_area(self):
        return 6 * self.side ** 2


# Sphere subclass
class Sphere(Shape3D):

    def __init__(self, radius):
        self.radius = radius

    def volume(self):
        return (4 / 3) * math.pi * self.radius ** 3

    def surface_area(self):
        return 4 * math.pi * self.radius ** 2


# Cylinder subclass
class Cylinder(Shape3D):

    def __init__(self, radius, height):
        self.radius = radius
        self.height = height

    def volume(self):
        return math.pi * self.radius ** 2 * self.height

    def surface_area(self):
        return 2 * math.pi * self.radius * (self.radius + self.height)


# Objects
cube = Cube(4)
sphere = Sphere(3)
cylinder = Cylinder(3, 5)

# Output
print("Cube Volume:", cube.volume())
print("Cube Surface Area:", cube.surface_area())

print("Sphere Volume:", sphere.volume())
print("Sphere Surface Area:", sphere.surface_area())

print("Cylinder Volume:", cylinder.volume())
print("Cylinder Surface Area:", cylinder.surface_area())
# Out:
# Cube Volume: 64
# Cube Surface Area: 96
# Sphere Volume: 113.09733552923254
# Sphere Surface Area: 113.09733552923255
# Cylinder Volume: 141.3716694115407
# Cylinder Surface Area: 150.79644737231007

# %%
#Abstraction
#Task26:
from abc import ABC, abstractmethod

# Abstract class
class Notification(ABC):

    @abstractmethod
    def send(self, message):
        pass
class EmailNotification(Notification):

    def send(self, message):
        return "Email Sent: " + message
class SMSNotification(Notification):

    def send(self, message):
        return "SMS Sent: " + message
email = EmailNotification()
sms = SMSNotification()
print(email.send("Welcome to Python"))
print(sms.send("Welcome to Python"))
# Out:
# Email Sent: Welcome to Python
# SMS Sent: Welcome to Python

# %%
#Abstraction
#Task27:
from abc import ABC, abstractmethod

# Abstract class
class Database(ABC):

    @abstractmethod
    def connect(self):
        pass

    @abstractmethod
    def query(self, sql):
        pass
class MySQLDatabase(Database):

    def connect(self):
        return "Connected to MySQL Database"

    def query(self, sql):
        return "MySQL Executing: " + sql
class MongoDatabase(Database):

    def connect(self):
        return "Connected to MongoDB Database"

    def query(self, sql):
        return "MongoDB Executing: " + sql

sql = MySQLDatabase()
m = MongoDatabase()
print(sql.connect())
print(sql.query("SELECT * FROM students"))

print(m.connect())
print(m.query("db.students.find()"))
# Out:
# Connected to MySQL Database
# MySQL Executing: SELECT * FROM students
# Connected to MongoDB Database
# MongoDB Executing: db.students.find()

# %%
#Abstraction
#Task28:
from abc import ABC, abstractmethod

# Abstract class
class GameCharacter(ABC):

    @abstractmethod
    def attack(self):
        pass
class Warrior(GameCharacter):

    def attack(self):
        return "Warrior attacks with a Sword"
class Archer(GameCharacter):

    def attack(self):
        return "Archer attacks with a Bow"
class Mage(GameCharacter):

    def attack(self):
        return "Mage attacks with Magic"
warrior = Warrior()
archer = Archer()
mage = Mage()
print(warrior.attack())
print(archer.attack())
print(mage.attack())
# Out:
# Warrior attacks with a Sword
# Archer attacks with a Bow
# Mage attacks with Magic

# %%
#Abstraction
#Task29:
from abc import ABC, abstractmethod

# Abstract class
class Transport(ABC):

    @abstractmethod
    def move(self):
        pass

    @abstractmethod
    def fuel_type(self):
        pass
class Car(Transport):

    def move(self):
        return "Car moves on roads"

    def fuel_type(self):
        return "Petrol"
class Train(Transport):

    def move(self):
        return "Train moves on railway tracks"

    def fuel_type(self):
        return "Electricity"
class Airplane(Transport):

    def move(self):
        return "Airplane flies in the sky"

    def fuel_type(self):
        return "Aviation Fuel"
c = Car()
t = Train()
a = Airplane()
print(c.move())
print("Fuel:", c.fuel_type())

print(t.move())
print("Fuel:", t.fuel_type())

print(a.move())
print("Fuel:", a.fuel_type())
# Out:
# Car moves on roads
# Fuel: Petrol
# Train moves on railway tracks
# Fuel: Electricity
# Airplane flies in the sky
# Fuel: Aviation Fuel

# %%
#Abstraction
#Task30:
from abc import ABC, abstractmethod

# Abstract class
class FileHandler(ABC):

    @abstractmethod
    def read(self):
        pass

    @abstractmethod
    def write(self, data):
        pass
class TextFileHandler(FileHandler):

    def read(self):
        return "Reading data from Text File"

    def write(self, data):
        return "Writing to Text File: " + data
class CSVFileHandler(FileHandler):

    def read(self):
        return "Reading data from CSV File"

    def write(self, data):
        return "Writing to CSV File: " + data
t = TextFileHandler()
c = CSVFileHandler()
print(t.read())
print(t.write("Hello World"))

print(c.read())
print(c.write("Name,Age"))
# Out:
# Reading data from Text File
# Writing to Text File: Hello World
# Reading data from CSV File
# Writing to CSV File: Name,Age
