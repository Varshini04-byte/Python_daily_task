# %% [markdown]
# 1. Load the Flight Price dataset into a Pandas DataFrame and display the first
# five rows.

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Varshini\\Downloads\Data_Train.xlsx - Sheet1.csv")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
df.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# 2. Find the number of rows and columns in the dataset.

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# 3. Display all column names in the dataset.

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# 4. Display the data types of all columns.

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# 5. Use df.info() to inspect the structure of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# 6. Check the number of missing values in each column.

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# 7. Check the percentage of missing values in each column.

# %%
df.isnull().mean()*100
# Out:
# Airline            0.000000
# Date_of_Journey    0.000000
# Source             0.000000
# Destination        0.000000
# Route              0.009361
# Dep_Time           0.000000
# Arrival_Time       0.000000
# Duration           0.000000
# Total_Stops        0.009361
# Additional_Info    0.000000
# Price              0.000000
# dtype: float64

# %% [markdown]
# 8. Display the unique values and frequency of each value in the Airline column.

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %% [markdown]
# 9. Display the frequency distribution of Total_Stops, including missing values.

# %%
df['Total_Stops'].value_counts(dropna=False)
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# NaN            1
# 4 stops        1
# Name: count, dtype: int64

# %% [markdown]
# 10.Convert Date_of_Journey into a datetime format.

# %%
df['Date_of_Journey']=pd.to_datetime(df['Date_of_Journey'])
df['Date_of_Journey']
# Out:
# 0       2019-03-24
# 1       2019-05-01
# 2       2019-06-09
# 3       2019-05-12
# 4       2019-03-01
#            ...
# 10678   2019-04-09
# 10679   2019-04-27
# 10680   2019-04-27
# 10681   2019-03-01
# 10682   2019-05-09
# Name: Date_of_Journey, Length: 10683, dtype: datetime64[ns]

# %% [markdown]
# 11.Extract the day from Date_of_Journey and create a day column.

# %%
df = pd.DataFrame({'date':['2024-01-15', '2024-02-20', '2024-03-25']})
df["Days"] = df['date'].str.split("-").str[2]
df["Days"]
# Out:
# 0    15
# 1    20
# 2    25
# Name: Days, dtype: object

# %% [markdown]
# 12.Extract the month from Date_of_Journey and create a month column.

# %%
df = pd.DataFrame({'date':['2024-01-15', '2024-02-20', '2024-03-25']})
df["Months"] = df['date'].str.split("-").str[1]
df["Months"]
# Out:
# 0    01
# 1    02
# 2    03
# Name: Months, dtype: object

# %% [markdown]
# 13.Extract the year from Date_of_Journey and create a year column.

# %%
df = pd.DataFrame({'date':['2024-01-15', '2024-02-20', '2024-03-25']})
df["Year"] = df['date'].str.split("-").str[0]
df["Year"]
# Out:
# 0    2024
# 1    2024
# 2    2024
# Name: Year, dtype: object

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Varshini\\Downloads\Data_Train.xlsx - Sheet1.csv")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# 14.Drop the original Date_of_Journey column after extracting the required
# features.

# %%
df.drop('Date_of_Journey',axis=1)
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Varshini\\Downloads\Data_Train.xlsx - Sheet1.csv")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# 15.Convert Dep_Time into datetime format and extract the departure hour into
# Dep_Hour.

# %%
df['Dep_Hour']=df['Dep_Time'].str.split(":").str[0].astype(int)
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df['Dep_Hour']=df['Dep_Time'].str.split(":").str[0].astype(int)
#       2 df.head()
#
# File ~\Untitled Folder\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~\Untitled Folder\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\Untitled Folder\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\Untitled Folder\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %% [markdown]
# 16.Extract the departure minute from Dep_Time and create Dep_Minute.

# %%
df['Dep_Minute']=df['Dep_Time'].dt.minute
df['Dep_Minute']
# Out:
# 0        20
# 1        50
# 2        25
# 3         5
# 4        50
#          ..
# 10678    55
# 10679    45
# 10680    20
# 10681    30
# 10682    55
# Name: Dep_Minute, Length: 10683, dtype: int32

# %% [markdown]
# 17.Drop the original Dep_Time column after extracting the required features.

# %%
df.drop('Dep_Time',axis=1)
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route            Dep_Time  Arrival_Time Duration  \
# 0                  BLR → DEL 2026-08-10 22:20:00  01:10 22 Mar   2h 50m
# 1      CCU → IXR → BBI → BLR 2026-08-10 05:50:00         13:15   7h 25m
# 2      DEL → LKO → BOM → COK 2026-08-10 09:25:00  04:25 10 Jun      19h
# 3            CCU → NAG → BLR 2026-08-10 18:05:00         23:30   5h 25m
# 4            BLR → NAG → DEL 2026-08-10 16:50:00         21:35   4h 45m
# ...                      ...                 ...           ...      ...
# 10678              CCU → BLR 2026-08-10 19:55:00         22:25   2h 30m
# 10679              CCU → BLR 2026-08-10 20:45:00         23:20   2h 35m
# 10680              BLR → DEL 2026-08-10 08:20:00         11:20       3h
# 10681              BLR → DEL 2026-08-10 11:30:00         14:10   2h 40m
# 10682  DEL → GOI → BOM → COK 2026-08-10 10:55:00         19:15   8h 20m
#
#       Total_Stops Additional_Info  Price  Dep_Hour  Dep_Minute
# 0        non-stop         No info   3897        22          20
# 1         2 stops         No info   7662         5          50
# 2         2 stops         No info  13882         9          25
# 3          1 stop         No info   6218        18           5
# 4          1 stop         No info  13302        16          50
# ...           ...             ...    ...       ...         ...
# 10678    non-stop         No info   4107        19          55
# 10679    non-stop         No info   4145        20          45
# 10680    non-stop         No info   7229         8          20
# 10681    non-stop         No info  12648        11          30
# 10682     2 stops         No info  11753        10          55
#
# [10683 rows x 13 columns]

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Varshini\\Downloads\Data_Train.xlsx - Sheet1.csv")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# 18.Extract only the time portion from Arrival_Time.

# %%
df['Arrival_Time']=df['Arrival_Time'].str.split().str[0]
df['Arrival_Time']
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10678    22:25
# 10679    23:20
# 10680    11:20
# 10681    14:10
# 10682    19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Varshini\\Downloads\Data_Train.xlsx - Sheet1.csv")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# 19.Extract the arrival hour and minute into Arrival_Hour and Arrival_Minute.

# %%
df['Arrival_Time'] = df['Arrival_Time'].str.split().str[0]
df['Arrival_Hour'] = df['Arrival_Time'].str.split(':').str[0].astype(int)
df['Arrival_Minute'] = df['Arrival_Time'].str.split(':').str[1].astype(int)
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20        01:10   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50        13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25        04:25      19h     2 stops
# 3            CCU → NAG → BLR    18:05        23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50        21:35   4h 45m      1 stop
# ...                      ...      ...          ...      ...         ...
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price  Arrival_Hour  Arrival_Minute
# 0             No info   3897             1              10
# 1             No info   7662            13              15
# 2             No info  13882             4              25
# 3             No info   6218            23              30
# 4             No info  13302            21              35
# ...               ...    ...           ...             ...
# 10678         No info   4107            22              25
# 10679         No info   4145            23              20
# 10680         No info   7229            11              20
# 10681         No info  12648            14              10
# 10682         No info  11753            19              15
#
# [10683 rows x 13 columns]

# %% [markdown]
# 20.Drop the original Arrival_Time column after extracting the required features.

# %%
df.drop('Arrival_Time',axis=1)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Duration Total_Stops Additional_Info  \
# 0                  BLR → DEL    22:20   2h 50m    non-stop         No info
# 1      CCU → IXR → BBI → BLR    05:50   7h 25m     2 stops         No info
# 2      DEL → LKO → BOM → COK    09:25      19h     2 stops         No info
# 3            CCU → NAG → BLR    18:05   5h 25m      1 stop         No info
# 4            BLR → NAG → DEL    16:50   4h 45m      1 stop         No info
# ...                      ...      ...      ...         ...             ...
# 10678              CCU → BLR    19:55   2h 30m    non-stop         No info
# 10679              CCU → BLR    20:45   2h 35m    non-stop         No info
# 10680              BLR → DEL    08:20       3h    non-stop         No info
# 10681              BLR → DEL    11:30   2h 40m    non-stop         No info
# 10682  DEL → GOI → BOM → COK    10:55   8h 20m     2 stops         No info
#
#        Price  Arrival_Hour  Arrival_Minute
# 0       3897             1              10
# 1       7662            13              15
# 2      13882             4              25
# 3       6218            23              30
# 4      13302            21              35
# ...      ...           ...             ...
# 10678   4107            22              25
# 10679   4145            23              20
# 10680   7229            11              20
# 10681  12648            14              10
# 10682  11753            19              15
#
# [10683 rows x 12 columns]

# %% [markdown]
# 21.Extract the hour component from Duration and create Duration_Hour. Handle
# invalid or missing extracted values appropriately.

# %%
df['Duration_Hour']=df['Duration'].astype(str).str.split("h").str[0]
df['Duration_Hour']=pd.to_numeric(df['Duration_Hour'],errors='coerce')
df['Duration_Hour']
# Out:
# 0         2.0
# 1         7.0
# 2        19.0
# 3         5.0
# 4         4.0
#          ...
# 10678     2.0
# 10679     2.0
# 10680     3.0
# 10681     2.0
# 10682     8.0
# Name: Duration_Hour, Length: 10683, dtype: float64

# %% [markdown]
# 22.Extract the minute component from Duration and create Duration_Minute.
# Handle invalid or missing extracted values appropriately.

# %%
df["Duration_Minute"] = pd.to_numeric(df["Duration"].str.split().str[1].str.replace("m", ""),errors="coerce")

df["Duration_Minute"]
# Out:
# 0        50.0
# 1        25.0
# 2         NaN
# 3        25.0
# 4        45.0
#          ...
# 10678    30.0
# 10679    35.0
# 10680     NaN
# 10681    40.0
# 10682    20.0
# Name: Duration_Minute, Length: 10683, dtype: float64

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Varshini\\Downloads\Data_Train.xlsx - Sheet1.csv")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# 23.Drop the original Duration column after creating the numerical duration
# features.

# %%
df.drop("Duration",axis=1)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun     2 stops
# 3            CCU → NAG → BLR    18:05         23:30      1 stop
# 4            BLR → NAG → DEL    16:50         21:35      1 stop
# ...                      ...      ...           ...         ...
# 10678              CCU → BLR    19:55         22:25    non-stop
# 10679              CCU → BLR    20:45         23:20    non-stop
# 10680              BLR → DEL    08:20         11:20    non-stop
# 10681              BLR → DEL    11:30         14:10    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 10 columns]

# %% [markdown]
# 24.Replace non-stop in Total_Stops with 0 stops.

# %%
df["Total_Stops"]=df["Total_Stops"].replace("non-stop",0)
df["Total_Stops"]
# Out:
# 0              0
# 1        2 stops
# 2        2 stops
# 3         1 stop
# 4         1 stop
#           ...
# 10678          0
# 10679          0
# 10680          0
# 10681          0
# 10682    2 stops
# Name: Total_Stops, Length: 10683, dtype: object

# %% [markdown]
# 25.Extract only the numerical value from Total_Stops and convert the column into
# an integer data type. Handle missing or invalid values appropriately.

# %%
df["Total_Stops"] = pd.to_numeric(df["Total_Stops"].astype(str).str.split().str[0],errors="coerce")

df["Total_Stops"] = df["Total_Stops"].fillna(0).astype(int)

df["Total_Stops"]
# Out:
# 0        0
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    0
# 10681    0
# 10682    2
# Name: Total_Stops, Length: 10683, dtype: int64

# %% [markdown]
# 27.Identify the missing values created in Route_3, Route_4, and Route_5 after
# splitting the route.

# %%
df[["Route_3", "Route_4", "Route_5"]].isnull().sum()
# Out:
# Route_3     3492
# Route_4     9117
# Route_5    10637
# dtype: int64

# %% [markdown]
# 28.Replace the missing values in the route columns with an appropriate value
# such as None.

# %%
df[["Route_1", "Route_2", "Route_3", "Route_4", "Route_5"]] = (df[["Route_1", "Route_2", "Route_3", "Route_4", "Route_5"]].fillna("None"))

df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration  Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m            0
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m            2
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h            2
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m            1
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m            1
# ...                      ...      ...           ...      ...          ...
# 10678              CCU → BLR    19:55         22:25   2h 30m            0
# 10679              CCU → BLR    20:45         23:20   2h 35m            0
# 10680              BLR → DEL    08:20         11:20       3h            0
# 10681              BLR → DEL    11:30         14:10   2h 40m            0
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m            2
#
#       Additional_Info  Price Route_1 Route_2 Route_3 Route_4 Route_5
# 0             No info   3897    BLR      DEL    None    None    None
# 1             No info   7662    CCU     IXR     BBI      BLR    None
# 2             No info  13882    DEL     LKO     BOM      COK    None
# 3             No info   6218    CCU     NAG      BLR    None    None
# 4             No info  13302    BLR     NAG      DEL    None    None
# ...               ...    ...     ...     ...     ...     ...     ...
# 10678         No info   4107    CCU      BLR    None    None    None
# 10679         No info   4145    CCU      BLR    None    None    None
# 10680         No info   7229    BLR      DEL    None    None    None
# 10681         No info  12648    BLR      DEL    None    None    None
# 10682         No info  11753    DEL     GOI     BOM      COK    None
#
# [10683 rows x 16 columns]

# %%
df=pd.read_csv("C:\\Users\\Varshini\\Downloads\Data_Train.xlsx - Sheet1.csv")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# 29.Drop the original Route column after creating and cleaning the route features.

# %%
df.drop("Route",axis=1,inplace=True)
df
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price
# 0      01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1             13:15   7h 25m     2 stops         No info   7662
# 2      04:25 10 Jun      19h     2 stops         No info  13882
# 3             23:30   5h 25m      1 stop         No info   6218
# 4             21:35   4h 45m      1 stop         No info  13302
# ...             ...      ...         ...             ...    ...
# 10678         22:25   2h 30m    non-stop         No info   4107
# 10679         23:20   2h 35m    non-stop         No info   4145
# 10680         11:20       3h    non-stop         No info   7229
# 10681         14:10   2h 40m    non-stop         No info  12648
# 10682         19:15   8h 20m     2 stops         No info  11753
#
# [10683 rows x 10 columns]

# %% [markdown]
# 30.After completing all data cleaning and feature engineering, separate the
# dataset into X (independent variables) and y (target variable), where Price
# is the target.

# %%
X = df.drop("Price", axis=1)
y = df["Price"]
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (10683, 9)
# y shape: (10683,)
