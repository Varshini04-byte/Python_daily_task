# %% [markdown]
# # Single Line Comment

# %%
#Varshini
#SRITW
#ECE

# %% [markdown]
# # Multi-line comment

# %%
#Varshini
#SRITW
#ECE

# %% [markdown]
# # Docstring

# %%
""" Varshini SRITW ECE """
# Out:
# ' Varshini SRITW ECE '

# %% [markdown]
# # 2.Identation Practice

# %%
if True:
    print("Hello World")
    print("Welcome to Python")
# Out:
# Hello World
# Welcome to Python

# %% [markdown]
# # 3. Variables Declaration

# %%
name=str(input("Enter the name "))
print(name,type(name))
age=int(input("Enter the age "))
print(age,type(age))
height=float(input("Enter the height "))
print(height,type(height))
is_student=True
print(type(is_student))
# Out:
# Enter the name abc
# abc <class 'str'>
# Enter the age 20
# 20 <class 'int'>
# Enter the height 5.6
# 5.6 <class 'float'>
# <class 'bool'>

# %% [markdown]
# # 4. Variable Naming Rules

# %%
#1st_name(The Variable should not start with the value)
#my name(In these there is no space is required)
#total@amount(The variable should not require any special symbols in between)
#class(It is a valid variable name because in python class is a keyword)
#MyVar(It is a valid variable)
#_score(It is a valid variable)
#99marks(It is a invalid variable)

# %% [markdown]
# # 5. Arithmetic Operators

# %%
A=int(input("Enter the value "))
B=int(input("Enter the value "))
print(A+B)
print(A-B)
print(A*B)
print(A/B)
print(A//B)
print(A%B)
print(A*B)
# Out:
# Enter the value 20
# Enter the value 40
# 60
# -20
# 800
# 0.5
# 0
# 20
# 800

# %% [markdown]
# # 6. Comparison Operator

# %%
a=int(input("Enter the value "))
b=int(input("Enter the value "))
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# Enter the value 60
# Enter the value 80
# False
# True
# False
# True
# False
# True

# %% [markdown]
# # 7. Assignment Operators

# %%
a=int(input("Enter the value "))
a += 10
print(a)
a -= 10
print(a)
a *= 10
print(a)
a /= 10
print(a)
a //= 10
print(a)
a %= 10
print(a)
a **= 10
print(a)
# Out:
# Enter the value 20
# 30
# 20
# 200
# 20.0
# 2.0
# 2.0
# 1024.0

# %% [markdown]
# # 8. Local vs Global Variable

# %%
college="SRITW"
def addition():
    student_name="Varshini"
    print(college,student_name)
addition()
# Out:
# SRITW Varshini

# %% [markdown]
# # 9. Simple Calculator

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %% [markdown]
# # 10. Temperature Converter

# %%
C=float(input("Enter the temperature value "))
f=(C*9/5)+32
print(f)
C=(f-32)*(5/9)
print(C)
# Out:
# Enter the temperature value 20
# 68.0
# 20.0

# %% [markdown]
# # 11. Area and Perimeter Calculator

# %%
r=int(input("Enter the value "))
pi=3.14
area=pi*r*r
print(area)
circumference=2*pi*r
print(circumference)
# Out:
# Enter the value 5
# 78.5
# 31.400000000000002

# %% [markdown]
# # 12.Student Grade Calculator

# %%
sub1=int(input("Enter the marks"))
sub2=int(input("Enter the marks"))
sub3=int(input("Enter the marks"))
sub4=int(input("Enter the marks"))
sub5=int(input("Enter the marks"))
total=sub1+sub2+sub3+sub4+sub5
p=(total/500)*100
if p>=90:
    print("A+")
elif p>=80:
    print("A")
elif p>=70:
     print("B")
elif p>=60:
     print("C")
else:
    print("fail")
# Out:
# Enter the marks60
# Enter the marks70
# Enter the marks80
# Enter the marks98
# Enter the marks99
# A

# %% [markdown]
# # 14. Logical Operators Practice

# %%
age=int(input("Enter the age :"))
salary=int(input("Enter the salary :"))
if(age>=18 and age<=60):
    if(salary>25000):
        print("person is eligible for loan")
    else:
        print("person is not eligible for loan")
# Out:
# Enter the age :26
# Enter the salary :30000
# person is eligible for loan

# %% [markdown]
# # 13.Swap Two Variables

# %%
#using third variable
a=int(input())
b=int(input())
temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# 2
# 4
# 4
# 2

# %%
#without using third variable
a=int(input())
b=int(input())
a,b=b,a
print(a)
print(b)
# Out:
# 6
# 10
# 10
# 6

# %%
x=10
print(str(x))
print(type(str(x)))
print(float(x))
print(type(float(x)))
print(bool(x))
print(type(bool(x)))
# Out:
# 10
# <class 'str'>
# 10.0
# <class 'float'>
# True
# <class 'bool'>

# %%
a=int(input("enter the value "))
b=int(input("enter the value "))
choice=int(input("enter the value "))
if choice == 1:
    print(a+b)
elif choice == 2:
    print(a-b)
elif choice == 3:
    print(a*b)
elif choice == 4:
    print(a/b)
elif choice == 5:
    print(a//b)
elif choice == 6:
    print(a%b)
elif choice == 7:
    print(a**b)
else:
    print("invalid")
# Out:
# enter the value 10
# enter the value 20
# enter the value 7
# 100000000000000000000

# %% [markdown]
# # Logical Operators(and,or,not)

# %%
age=int(input("Enter the age: "))
marks=int(input("Enter the marks: "))
if(age>=18 and age<=25):
    if(marks>=60):
        print("Student is eligible for admission")
    else:
        print("Student is not eligible for admission")
# Out:
# Enter the age: 20
# Enter the marks: 55
# Student is not eligible for admission

# %%
username="admin"
password="12345"
if(username=="admin" and password=="12345"):
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Login Successful

# %%
num=int(input("Enter the num: "))
if(50<=num>=100)and(num%5!=0):
    print("divisible")
else:
    print("Not divisible")
# Out:
# Enter the num: 65
# Not divisible

# %%
a=input("Enter the value: ")
b=input("Enter the value: ")
c=input("Enter the value: ")
if a>b and a>c:
    print("a is largest")
elif b>a and b>c:
    print("b is largest")
else:
        print("c is largest")
# Out:
# Enter the value: 10
# Enter the value: 20
# Enter the value: 30
# c is largest

# %% [markdown]
# # String and string slicing

# %%
s=input("Enter name: ")
print(s.upper())
print(s.lower())
print(len(s))
print(s[:3])
print(s[5:])
# Out:
# Enter name: varshini
# VARSHINI
# varshini
# 8
# var
# ini

# %%
s=input("Enter sentence: ")
print(s[:10])
print(s[-10:])
print(s[5:16])
print(s[::2])
# Out:
# Enter sentence: javaprogramming
# javaprogra
# rogramming
# rogramming
# jvpormig

# %%
a=input("Enter word: ")
if a==a[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter word: madam
# Palindrome

# %%
a=input("Enter email")
parts=a.split("@")
print(parts[0])
print(parts[1])
# Out:
# Enter emailvarshini@gmail.com
# varshini
# gmail.com

# %% [markdown]
# # String+Logical

# %%
p=input("Enter Password")
if len(p)>=8 and ("@" in p or "#" in p):
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter Passwordvarshini@04
# Strong Password

# %%
#logical Operators
sub1=int(input("Enter the marks"))
sub2=int(input("Enter the marks"))
sub2=int(input("Enter the marks"))
if sub1>=40 and sub2>=40 and sub2>=40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter the marks30
# Enter the marks40
# Enter the marks35
# Fail

# %%
#Logical Operators+User Input
a=int(input("Enter value: "))
if a>0 and a%2 == 0:
    print("Positive and even")
elif a<0 or a%2 != 0:
    print("Negative or odd")
# Out:
# Enter value: 5
# Negative or odd

# %%
#String Operations
a=str(input("Enter name: "))
print(a[::-1])
count=(a.count("a")+a.count("e")+a.count("i")+a.count("o")+a.count("u"))
print("no of vowels:",count)
print(a[1:-1])
# Out:
# Enter name: hanamkonda
# adnokmanah
# no of vowels: 4
# anamkond

# %%
#String Slicing
a=input("Enter mobile number")
print(a[:3])
print(a[6:])
print(a[3:6])
# Out:
# Enter mobile number6281555986
# 628
# 5986
# 155

# %%
#Mixed(String+Logical)
a=str(input("Enter string: "))
if len(a) > 5 and a[0]== 'A' or 'a':
    print("Valid String")
else:
    print("Invalid String")
# Out:
# Enter string: Varshini
# Valid String

# %% [markdown]
# # String Slicing

# %%
 a=str(input("Enter string: "))
print(a[:5])
# Out:
# Enter string: varshitha
# varsh

# %%
a=str(input("Enter string: "))
print(a[5:])
# Out:
# Enter string: varshitha
# itha

# %%
a=str(input("Enter string: "))
print(a[2:7])
# Out:
# Enter string: varshitha
# rshit

# %%
a=str(input("Enter string: "))
print(a[1::2])
# Out:
# Enter string: varshitha
# asih

# %%
name="Sumit Kumar Sharma"
parts=name.split(" ")
print("first name",parts[0])
print("last name",parts[2])
# Out:
# first name Sumit
# last name Sharma

# %% [markdown]
# # Case Conversion

# %%
a=str(input("Enter string: "))
print(a.upper())
print(a.lower())
print(a.title())
print(a.capitalize())
# Out:
# Enter string: varshitha
# VARSHITHA
# varshitha
# Varshitha
# Varshitha

# %%
a="My bestfriend name is Buffalooo"
print(a)
print(a.title())
# Out:
# My bestfriend name is Buffalooo
# My Bestfriend Name Is Buffalooo

# %%
a="she loves Chocolate"
print(a.islower())
print(a.isupper())
print(a)
# Out:
# False
# False
# she loves Chocolate

# %% [markdown]
# # String Check Methods

# %%
a=str(input("enter string: "))
a.isalpha()
# Out:
# enter string: akshitha
# True

# %%
a=str(input("enter string: "))
a.isalnum()
# Out:
# enter string: varshini
# True

# %%
a=str(input("enter string: "))
a.isdigit()
# Out:
# enter string: varshini
# False

# %%
a="varshini04"
if len(a)>=8:
    print("Valid Password")
else:
    print("Invalid Password")
# Out:
# Valid Password

# %% [markdown]
# # find() and index()

# %%
a="varshini"
ch="a"
c=a.find(ch)
print(c)
# Out:
# 1

# %%
#when it is exists
a=input("Enter a string: ")
word=input("Enter a word: ")
b=a.find(word)
if b == -1:
    print(-1)
else:
    print(b)
# Out:
# Enter a string: python is easy
# Enter a word: easy
# 10

# %%
#when it is not exists
a=input("Enter a string: ")
word=input("Enter a word: ")
b=a.find(word)
if b == -1:
    print(-1)
else:
    print(b)
# Out:
# Enter a string: python is easy
# Enter a word: apple
# -1

# %%
s="Python is easy"
a=s.index("Python")
print(a)
# Out:
# 0

# %%
s="python is easy"
ch="z"
a=s.find(ch)
print(a)
b=a.index("ch")
print(b)
# Out:
# -1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 5
#       3 a=s.find(ch)
#       4 print(a)
# ----> 5 b=a.index("ch")
#       6 print(b)
#
# AttributeError: 'int' object has no attribute 'index'

# %%
name="Burgula Varshini"
print(name.upper())
space=name.find(" ")
first_name = name[:space]
last_name = name[space+1:]
print("first name:",first_name)
print("last name:",last_name)
print(space)
# Out:
# BURGULA VARSHINI
# first name: Burgula
# last name: Varshini
# 7

# %% [markdown]
# a="1234567898"
# if a.isdigit() and len(a)<=10:
#     print("it contains 10 digits")
# else:
#     print("No")

# %%
s=input("Enter a string: ")
b=(s[::-1])
print(b)
print(s.title())
if s==b:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a string: pythonprogramming
# gnimmargorpnohtyp
# Pythonprogramming
# Not Palindrome
