# %% [markdown]
# # Day7(Sets and if condition)

# %%
sets={1,2,3,4,1}
print(sets)
# Out:
# {1, 2, 3, 4}

# %%
a1=set()
a1.add(1)
a1.add(2)
a1.add(3)
print(a1)
# Out:
# {1, 2, 3}

# %%
s={10,20,30}
s.update([40,50,60])
print(s)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
s1={10,20,30,40}
s1.remove(20)
print(s1)
s1.discard(20)
print(s1)
# Out:
# {40, 10, 30}
# {40, 10, 30}

# %%
A={1,2,3,4}
B={3,4,5,6}
A.union(B)
print(A)
C=A.intersection(B)
print(C)
D=A.difference(B)
print(D)
# Out:
# {1, 2, 3, 4}
# {3, 4}
# {1, 2}

# %%
sets={10,20,30,40}
if 25 in sets:
    print("Present")
#else:
   # print("Not Present")

# %%
list1=[1,2,2,3,4,4,5]
set1=set(list1)
print(set1)
print(len(set1))
# Out:
# {1, 2, 3, 4, 5}
# 5

# %%
set1=set()
a=input()
b=input()
c=input()
d=input()
e=input()
set1.add(a)
set1.add(b)
set1.add(c)
set1.add(d)
set1.add(e)
print(set1)
# Out:
# 1
# 2
# 3
# 4
# 5
# {'3', '4', '1', '5', '2'}

# %%
A={1,2,3,}
B={3,4,5,}
A.difference(B)
# Out:
# {1, 2}

# %%
set2=set()
l1=[1,2,3]
set2.update([1,2,3])
print(set2)
# Out:
# {1, 2, 3}

# %%
age=int(input())
if age>=18:
    print("eligible to vote")
# Out:
# 18
# eligible to vote

# %%
a=int(input())
if a>0:
    print("Positive")
elif a<0:
    print("negative")
else:
    print("zero")
# Out:
# 4
# Positive

# %%
a=10
b=20
if a>b:
    print("a")
else:
    print("b")
# Out:
# b

# %%
ch=input()
v="a,e,i,o,u"
if ch in v:
    print("yes")
else:
    print("no")
# Out:
# a
# yes

# %%
a=int(input("Enter the marks: "))
if a>=90:
    print("A")
elif a>=80:
    print("B")
elif a>=70:
    print("C")
else:
    print("Fail")
# Out:
# Enter the marks: 90
# A

# %%
a=input()
b=input()
c=input()
if a>b and a>c:
    print("a is largest")
elif b>a and b>c:
    print("b is largest")
else:
    print("c is largest")
# Out:
# 2
# 15
# 60
# c is largest

# %%
a=60
if a%2==0 and a>50:
    print("even and greater")
# Out:
# even and greater

# %%
username=input()
password=input()
if username=="admin" and password=="1234":
    print("Login successful")
else:
     print("Login Failed")
# Out:
# admin
# 1234
# Login successful

# %%
year=int(input())
if year%4==0 and year%100!=0 or year%400:
    print("leap year")
else:
    print("not leap year")
# Out:
# 2024
# leap year

# %%
a=input()
b=input()
c=input()
if a+b>c or b+c>a or c+a>b:
    print("valid triangle")
else:
    print("not valid triangle")
# Out:
# 2
# 3
# 4
# valid triangle

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
    print("a is largest")
elif b>a and b>c:
    print("b is largest")
else:
    print("c is largest")
if a==b==c:
    print("all three num are equal")
# Out:
# 2
# 2
# 2
# c is largest
# all three num are equal

# %%
year=int(input())
if year%4==0 and year%100!=0 or year%400:
    print("leap year")
else:
    print("not leap year")
# Out:
# 2023
# leap year

# %%
a=input()
b=input()
c=input()
if a+b>c or b+c>a or c+a>b:
    print("valid triangle")
else:
    print("not valid triangle")
if a==b==c:
    print("equilateral")
elif a==b!=c or a!=b==c or c==a!=b:
    print("isosceles")
else:
    print("Scalene")
# Out:
# 4
# 7
# 9
# valid triangle
# Scalene

# %%
sub1=int(input("enter marks: "))
sub2=int(input("enter marks: "))
sub3=int(input("enter marks: "))
sub4=int(input("enter marks: "))
sub5=int(input("enter marks: "))
sub6=int(input("enter marks: "))
T=sub1+sub2+sub3+sub4+sub5+sub6
per=(T/600)*100
print(per)
print(T)
if per>=90:
    print("A+")
elif per>80 or T<89:
    print("A")
elif per>70 or T<79:
    print("B")
elif per>60 or T<69:
    print("C")
else:
    print("Fail")
# Out:
# enter marks: 78
# enter marks: 90
# enter marks: 67
# enter marks: 56
# enter marks: 45
# enter marks: 80
# 69.33333333333334
# 416
# C

# %%
username=input()
password=input()
age=int(input())
if username=="admin" and password=="python123" and age>=18:
    print("Login Successful")
elif age<18:
    print("You are too young to login")
else:
    print("Invalid Credentials")
# Out:
# admin
# python123
# 18
# Login Successful

# %% [markdown]
# # Day8(if-else)

# %%
a=int(input())
if a>=0:
    print("positive")
else:
    print("negative")
# Out:
# 8
# positive

# %%
age=int(input())
if age>=18:
    print("You can vote")
# Out:
# 20
# You can vote

# %%
n1=int(input())
n2=int(input())
if n1>n2:
    print("n1 is larger")
else:
    print("n2 is larger")
# Out:
# 5
# 8
# n2 is larger

# %%
num=int(input())
if num%2==0:
    print("even")
else:
    print("odd")
# Out:
# 7
# odd

# %%
a=input()
if a.islower():
    print("It is a lower")
elif a.isupper():
    print("It is a upper")
# Out:
# A
# It is a upper

# %%
marks=int(input())
if marks>=40:
    print("Pass")
else:
    print("Fail")
# Out:
# 50
# Pass

# %%
num1=int(input())
if num1%5==0:
    print("divisible by 5")
else:
    print("not divisible by 5")
# Out:
# 10
# divisible by 5

# %%
p=int(input())
if p>0:
    print("Positive")
elif p<0:
    print("Negative")
else:
    print("Zero")
# Out:
# -1
# Negative

# %%
a1=int(input())
b1=int(input())
c1=int(input())
if a1>b1 and a1>c1:
    print("a1 is largest")
if b1>a1 and b1>c1:
    print("b1 is largest")
else:
    print("c1 is largest")
# Out:
# 5
# 8
# 6
# b1 is largest

# %%
y=int(input())
if y%4==0 and y%100!=0 or y%400==0:
    print("it is a leap year")
else:
     print("it is not a leap year")
# Out:
# 2000
# it is a leap year

# %%
char=input()
var="a,e,i,o,u"
if char in var:
    print("Vowel")
else:
    print("consonant")
# Out:
# m
# consonant

# %%
sal=int(input())
if sal>50000:
    print("High")
elif sal>30000:
    print("Medium")
else:
    print("Low")
# Out:
# 40000
# Medium

# %%
tem=int(input("enter temperature value in celsius: "))
if tem>30:
    print("Hot")
elif tem>=20 and tem<=30:
    print("Warm")
else:
    print("Cold")
# Out:
# enter temperature value in celsius: 25
# Warm

# %%
username=input()
password=input()
if username=="varsh" and password=="1234":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# varsh
# 1234
# Login Successful

# %%
p=input()
q=input()
r=input()
if p+q>r or q+r>p or r+p>q:
    print("valid triangle")
else:
    print("not valid triangle")
if p==q==r:
    print("equilateral")
elif p==q!=r or p!=q==r or r==p!=q:
    print("isosceles")
else:
    print("Scalene")
# Out:
# 23
# 30
# 50
# valid triangle
# Scalene

# %%
st1=int(input("enter marks: "))
st2=int(input("enter marks: "))
st3=int(input("enter marks: "))
st4=int(input("enter marks: "))
st5=int(input("enter marks: "))
T=st1+st2+st3+st4+st5
per=(T/500)*100
print(per)
if per>=90:
    print("A+")
elif per>80 or T<89:
    print("A")
elif per>70 or T<79:
    print("B")
elif per>60 or T<69:
    print("C")
else:
    print("Fail")
# Out:
# enter marks: 60
# enter marks: 80
# enter marks: 99
# enter marks: 90
# enter marks: 85
# 82.8
# A

# %%
n=int(input())
if n%3==0 and n%5==0:
    print("FizzBuzz")
elif n%3==0:
    print("Fizz")
elif n%5==0:
    print("Buzz")
else:
    print("Number",n)
# Out:
# 4
# Number 4

# %%
age=int(input())
gen=str(input())
if age>=18 and gen=="Male":
    print("Eligible for Army")
elif age>=18 and gen=="Female":
    print("Eligible for Other Services")
else:
    print("Not Eligible")
# Out:
# 21
# Female
# Eligible for Other Services

# %%
ch1=input()
if ch1.isupper():
    print("It is a upper")
elif ch1.islower():
    print("It is a lower")
elif ch1.isdigit():
    print("It is a digit")
else:
    print("Special character")
# Out:
# 2
# It is a digit

# %%
n1=int(input())
n2=int(input())
n3=int(input())
if n1<n2 and n1<n3 and n2<n3:
    print("ascending order:",n1,n2,n3)
elif n1<n3 and n1<n2 and n3<n2:
    print("ascending order:",n2,n3,n2)
elif n2<n1 and n2<n3 and n1<n3:
    print("ascending order:",n2,n1,n3)
elif n2<n3 and n2<n1 and n3<n1:
    print("ascending order:",n2,n3,n1)
elif n3<n1 and n3<n2 and n1<n2:
    print("ascending order:",n3,n1,n2)
else:
    print("ascending order",n3,n2,n1)
# Out:
# 6
# 7
# 5
# ascending order: 5 6 7

# %% [markdown]
# # Task2(if-elif)

# %%
v=int(input())
if v>0:
    print("Positive")
elif v<0:
    print("Negative")
else:
    print("Zero")
# Out:
# 0
# Zero

# %%
age=int(input())
if age>=18:
    print("person can enter a movie theater")
else:
    print("person cannot enter a movie theater")
# Out:
# 12
# person cannot enter a movie theater

# %%
h=int(input())
if h%2==0:
    print("divisible by 2")
else:
    print("not divisible by 2")
# Out:
# 4
# divisible by 2

# %%
n1=int(input())
n2=int(input())
if n1>n2:
    print("greater num",n1)
else:
    print("greater num",n2)
# Out:
# 5
# 6
# greater num 6

# %%
m=input()
if m.islower():
    print("It is a lower")
elif m.isupper():
    print("It is a upper")
# Out:
# a
# It is a lower

# %%
y1=int(input())
if y1%4==0 and y1%100!=0 or y1%400==0:
    print("it is a leap year")
else:
     print("it is not a leap year")
# Out:
# 2001
# it is not a leap year

# %%
t=int(input())
if t<12:
    print("Morning")
elif t>12 and t<17:
    print("Afternoon")
else:
    print("Evening")
# Out:
# 13
# Afternoon

# %%
m1=int(input())
if m1>=75:
    print("Distinction")
elif m1>=35 and m1<=74:
    print("Pass")
else:
    print("Fail")
# Out:
# 99
# Distinction

# %%
b1=int(input())
b2=int(input())
b3=int(input())
if b1>b2 and b1>b3:
    print("largest num",b1)
elif b2>b1 and b2>b3:
    print("largest num",b2)
else:
    print("largest num",b3)
# Out:
# 15
# 30
# 20
# largest num 30

# %%
u=int(input())
if u<100:
    bill=u*2
elif u>=100 and u<=300:
    bill=u*4
elif u>300:
    bill=6*u
print("bill",bill)
# Out:
# 400
# bill 2400

# %%
a=input()
a1=input()
a2=input()
if a==a1==a2:
    print("Equilateral")
elif a==a1!=a2 or a!=a1==a2 or a2==a!=a1:
    print("Isosceles")
else:
    print("Scalene")
# Out:
# 5
# 5
# 9
# Isosceles

# %%
s1=int(input())
if s1>50000:
    bonus=s1*20/100
elif s1>=30000 and s1<=50000:
    bonus=s1*10/100
else:
    bonus=s1*5/100
print("bonus",bonus)
# Out:
# 40000
# bonus 4000.0

# %%
n=int(input())
if n%3==0 and n%5==0:
    print("multiple of both 3 and 5")
elif n%3==0:
    print("multiple of only 3")
elif n%5==0:
    print("multiple of only 5")
else:
    print("None")
# Out:
# 15
# multiple of both 3 and 5

# %%
p=int(input())
if p>=0 and p<=12:
    print("child")
elif p>=13 and p<=19:
    print("Teenager")
elif p>=20 and p<=59:
    print("Adult")
else:
    print("Senior citizens")
# Out:
# 18
# Teenager

# %%
a1=int(input())
if a1<=5:
    print("ticket price isFree")
elif a1>=5 and a1<=18:
    print("ticket price is 100")
elif a1>=20 and a1<=59:
    print("ticket price is 200")
else:
    print("ticket price is 150")
# Out:
# 60
# ticket price is 150

# %%
income=int(input())
if income<=250000:
    tax=0
elif income>=250000 and income<=500000:
    tax=income*5/100
elif income>=500000 and income<=1000000:
    tax=income*20/100
elif income>=1000000:
    tax=income*30/100
print("tax",tax)
# Out:
# 400000
# tax 20000.0

# %%
shp=int(input())
if shp>5000:
    dis=shp*30/100
elif shp>=2000 and shp<=5000:
    dis=shp*20/100
else:
    dis=shp*10/100
final_shp=shp-dis
print("dis", dis)
print("final shp", final_shp)
# Out:
# 3000
# dis 600.0
# final shp 2400.0

# %%
r=int(input("Enter employee performance" ))
if r>=90:
    print("Excellent")
elif r>=70 and r<=89:
    print("Good")
elif r>=50 and r<=69:
    print("Average")
else:
    print("Poor")
# Out:
# Enter employee performance80
# Good

# %%
k1=input()
k2=input()
k3=input()
if k1+k2>k3 or k1+k3>k2 or k2+k3>k1:
    print("Valid triangle")
else:
    print("not valid triangle")
# Out:
# 4
# 5
# 10
# Valid triangle

# %%
#quadratic equation
a=int(input("enter value: "))
b=int(input("enter value: "))
c=int(input("enter value: "))
q=b*b-4*a*c
if q>0:
    print("Two real and distinct roots")
elif q==0:
    print("Two real and equal roots")
else:
    print("Imaginary roots")
# Out:
# enter value: 4
# enter value: 5
# enter value: 6
# Imaginary roots

# %%
#mini calculator
e=int(input())
f=int(input())
choice=int(input("Enter the choice: "))
if choice==1:
    print("Addition: ",e+f)
elif choice==2:
    print("Subtraction: ",e-f)
elif choice==3:
    print("Multiplication: ",e*f)
elif choice==4:
    print("Division: ",e/f)
else:
    print("Invalid")
# Out:
# 6
# 8
# Enter the choice: 1
# Addition:  14

# %%
#season based month number
month=int(input("Enter the month: "))
if month==12 or month==1 or month==2:
    print("Winter")
elif month==3 or month==4 or month==5:
    print("summer")
elif month==6 or month==7 or month==8:
    print("monsoon")
elif month==9 or month==10 or month==11:
    print("Autumn")
else:
    print("Invalid")
# Out:
# Enter the month: 3
# summer

# %%
#ATM
balance=2000
choice=int(input("enter choice: "))
if choice==1:
    print("Balance amount",Balance)
elif choice==2:
    amount=int(input())
    if amount<=balance:
        balance=balance-amount
        print("remaining balance: ",balance)
    else:
        print("not sufficient")
elif choice==3:
    amount=int(input())
    balance=balance+amount
    print("balance: ",balance)
else:
    print("Invalid")
# Out:
# enter choice: 2
# 1000
# remaining balance:  1000
