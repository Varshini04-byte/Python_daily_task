# %% [markdown]
# # Easy level

# %%
str=input("Enter the string")
str.replace(" ","_")
# Out:
# Enter the stringdata science
# 'data_science'

# %%
s=" Python "
print(s.strip())
# Out:
# Python

# %%
s="Hello world"
print(s.startswith("Hello"))
# Out:
# True

# %%
a="Hello World"
print(a.endswith(".com"))
# Out:
# False

# %%
str="apple,banana,mango"
str.split(",")
# Out:
# ['apple', 'banana', 'mango']

# %%
a=["apple","banana","mango","grapes","pineapple"]
(" ".join(a))
# Out:
# 'apple banana mango grapes pineapple'

# %%
list=["Python ","is"," awesome"]
list[0].strip() + " " + list[1].strip() + " " + list[2].strip()
# Out:
# 'Python is awesome'

# %%
text = "python"
list[0].strip()
# Out:
# 'Python'

# %%
list[0]=list[0].strip()
list[1]=list[1].strip()
list[2]=list[2].strip()

# %%
list
# Out:
# ['Python', 'is', 'awesome']

# %%
name="Rahul Kumar Sharma"
parts=name.split(" ")
print("first name is",parts[0])
print("last name is",parts[2])
# Out:
# first name is Rahul
# last name is Sharma

# %%
a=input("Enter sentence: ")
b=a.split(" ")
print(b)
print(len(b))
# Out:
# Enter sentence: my name is varshini
# ['my', 'name', 'is', 'varshini']
# 4

# %%
s="varshini04@gmail.com"
print(s.endswith("@gmail.com"))
# Out:
# True

# %%
string="Hello World Python"
k=string.replace("World","Everyone")
print(k)
# Out:
# Hello Everyone Python

# %%
a="hello world"
print(a.strip())
print(a.title())
print(a.startswith("Hello"))
# Out:
# hello world
# Hello World
# False

# %%
c1=input()
c2=input()
c3=input()
c4=input()
c5=input()
cities=[c1,c2,c3,c4,c5]
result=("\n".join(cities))
print(result)
# Out:
# hyd
# wgl
# hnk
# hsp
# kphp
# hyd
# wgl
# hnk
# hsp
# kphp

# %%
a=input()
b=a.split(" ")
print(b)
c=(" ".join(b))
print(c)
d=c.replace("bad","good")
print(d)
# Out:
# bad morning sir
# ['bad', 'morning', 'sir']
# bad morning sir
# good morning sir

# %%
list=["10","20","30","40"]
("-".join(list))
# Out:
# '10-20-30-40'

# %%
a=input("Enter sentence")
b=a.split(" ")
print(b)
print(a.startswith("aeiou"))
print(b.remove("aeoiu"))
# Out:
# Enter sentenceshe is an elder sister
# ['she', 'is', 'an', 'elder', 'sister']
# False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 5
#       3 print(b)
#       4 print(a.startswith("aeiou"))
# ----> 5 print(b.remove("aeoiu"))
#
# ValueError: list.remove(x): x not in list

# %%
list=["ammulu,sweety,nani,akshi,varsha"]
a=(",".join(list))
b=a.replace("ammulu","New Student")
print(b)
# Out:
# New Student,sweety,nani,akshi,varsha

# %%
a="iam a good student"
b=a.replace(" ","-")
print(b)
c=b.split("-")
if len(c[0])>4:
    print(c[0])
elif len(c[1])>4:
    print(c[1])
elif len(c[2])>4:
    print(c[2])
elif len(c[3])>4:
    print(c[3])
# Out:
# iam-a-good-student
# student

# %%
string="I am eating Biryani"
a=string.replace("Biryani","Chicken")
print(a)
b=(a.strip())
print(b)
c=b.split(" ")
print(c)
d=(" ".join(a))
print(d)
# Out:
# I am eating Chicken
# I am eating Chicken
# ['I', 'am', 'eating', 'Chicken']
# I   a m   e a t i n g   C h i c k e n

# %%
b=input()
a=b.split(".")
print(a)
a[0]=a[0].strip()
a[1]=a[1].strip()
a[2]=a[2].strip()
c=("\n".join(a))
print(c)
# Out:
# i am varshini.i am studying college.i love chocolates.
# ['i am varshini', 'i am studying college', 'i love chocolates', '']
# i am varshini
# i am studying college
# i love chocolates

# %% [markdown]
# # Day 5(List Data Types)

# %%
list=["ammu","sweety","frooty","varsha","sony"]
print(list)
# Out:
# ['ammu', 'sweety', 'frooty', 'varsha', 'sony']

# %%
num=[10,20,30,40,50]
print(type(num))
print(len(num))
# Out:
# <class 'list'>
# 5

# %%
list=[]
list.append(1)
list.append(2)
list.append(3)
print(list)
# Out:
# [1, 2, 3]

# %%
lst=[1,2,3]
lst.extend([4,5,6])
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a=[10,20,30,40]
a.insert(2,100)
print(a)
# Out:
# [10, 20, 100, 30, 40]

# %%
a=[10,20,50,30,50]
a.remove(50)
print(a)
# Out:
# [10, 20, 30, 50]

# %%
a=[5,10,15,20]
a.pop(3)
print(a)
# Out:
# [5, 10, 15]

# %%
a=[1,2,3,4,5]
a.clear()
print(a)
# Out:
# []

# %%
a=[10,15,25,30,40]
a.index(25)
# Out:
# 2

# %%
a=[7,2,7,5,7,8]
a.count(7)
# Out:
# 3

# %%
a=[45,12,78,23,56]
a.sort()
print(a)
# Out:
# [12, 23, 45, 56, 78]

# %%
a=[45,12,78,23,56]
a.sort(reverse=True)
print(a)
# Out:
# [78, 56, 45, 23, 12]

# %%
fruits=["apple","banana","mango","orange"]
fruits.reverse()
print(fruits)
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
org=[1,2,3,4]
a=org.copy()
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a="I love python"
w=a.split(" ")
print(w)
# Out:
# ['I', 'love', 'python']

# %%
a=[1,2,3,4,5]
a.append(6)
a.append(7)
a.append(8)
print(a)
b=a.sort(reverse=True)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
a=["python","c-lang","java"]
a.pop()
print(a)
b=len(a)
print(b)
# Out:
# ['python', 'c-lang']
# 2

# %%
a=["warangal","delhi","paris","vizag","kerala"]
a.reverse()
print(a)
# Out:
# ['kerala', 'vizag', 'paris', 'delhi', 'warangal']

# %%
a=[10,20,30,20,40,20]
a.remove(20)
print(a)
a.remove(20)
print(a)
a.remove(20)
print(a)
# Out:
# [10, 30, 20, 40, 20]
# [10, 30, 40, 20]
# [10, 30, 40]

# %%
a=[50,65,90,80,75,99]
a.sort()
print(a)
print("lowestmarks:",a[0])
print("highestmarks:",a[-1])
# Out:
# [50, 65, 75, 80, 90, 99]
# lowestmarks: 50
# highestmarks: 99

# %% [markdown]
# # Day6(tuples and dict)

# %%
dict={"Name":"varshini","age":20,"city":"warangal"}
print(dict)
# Out:
# {'Name': 'varshini', 'age': 20, 'city': 'warangal'}

# %%
d={"a":1,"b":2,"c":3}
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d={"a":1,"b":2}
d.values()
# Out:
# dict_values([1, 2])

# %%
d={"name":"varshini","age":20}
d.get("name")
# Out:
# 'varshini'

# %%
a=(1,2,2.3,4,5)
print(type(a))
print(len(a))
# Out:
# <class 'tuple'>
# 5

# %%
tup=(10,20,30,40,50)
tup.count(20)
# Out:
# 1

# %%
a=(10,20,30,40)
a.index(30)
# Out:
# 2

# %%
dict={}
dict["ab"]=10
dict["cd"]=20
dict["ef"]=30
print(dict)
# Out:
# {'ab': 10, 'cd': 20, 'ef': 30}

# %%
d={"a":1,"b":2}
d.update({"c":3,"d":4})
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
student={"name":"rahul","age":22,"city":"delhi"}
student.pop("age")
print(student)
# Out:
# {'name': 'rahul', 'city': 'delhi'}

# %%
d={"x":10,"y":20,"z":30}
d.popitem()
# Out:
# ('z', 30)

# %%
original={"a":1,"b":2}
original.copy()
# Out:
# {'a': 1, 'b': 2}

# %%
keys=["red","green","blue"]
a=dict.fromkeys(keys,0)
print(a)
# Out:
# {'red': 0, 'green': 0, 'blue': 0}

# %%
tup=("name",22.3,"varsh",2)
tup.update("age")
print(tup)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 tup=("name",22.3,"varsh",2)
# ----> 2 tup.update("age")
#       3 print(tup)
#
# AttributeError: 'tuple' object has no attribute 'update'

# %%
d={"name":"varshini"}
d.setdefault("age",20)
print(d)
# Out:
# {'name': 'varshini', 'age': 20}

# %%
dict={"name":"varshini","age":20}
dict.update({"mob-no":'1234'})
print(dict)
dict.popitem()
print(dict)
# Out:
# {'name': 'varshini', 'age': 20, 'mob-no': '1234'}
# {'name': 'varshini', 'age': 20}

# %%
tup=(1,2,3,4,5,6)
a=tup.index(3)
print(a)
tup.count(3)
# Out:
# 2
# 1

# %%
n1=input()
m1=int(input())
d[n1]=m1
n2=input()
m2=int(input())
d[n2]=m2
n3=input()
m3=int(input())
d[n3]=m3
print(d)
# Out:
# varsha
# 90
# ammu
# 89
# frooty
# 99
# {'name': 'varshini', 'age': 20, 'varsha': 90, 'ammu': 89, 'frooty': 99}

# %%
data={"a":10,"b":20,"c":10}
data.items()
print(data)
#data.pop(2
# Out:
# {'a': 10, 'b': 20, 'c': 10}

# %%
dict={"a":2,"b":3,"c":4,"d":5,"e":6}
dict.copy()
print(dict)
dict.clear()
print(dict)
# Out:
# {'a': 2, 'b': 3, 'c': 4, 'd': 5, 'e': 6}
# {}

# %%
d={"name":"varsha","age":20,"num":123,"color":"blue"}
d.update({"food":"biryani"})
print(d)
d.popitem()
print(d)
d.items()
print(d)
# Out:
# {'name': 'varsha', 'age': 20, 'num': 123, 'color': 'blue', 'food': 'biryani'}
# {'name': 'varsha', 'age': 20, 'num': 123, 'color': 'blue'}
# {'name': 'varsha', 'age': 20, 'num': 123, 'color': 'blue'}

# %%
t=(10,25,30,35,25)
print(t.index(25))
print(t.count(25))
a=list(t)
print(a)
a.sort(reverse=True)
print(a)
# Out:
# 1
# 2
# [10, 25, 30, 35, 25]
# [35, 30, 25, 25, 10]

# %%
a1=input()
b1=int(input())
a2=input()
b2=int(input())
a3=input()
b3=int(input())
a4=input()
b4=int(input())
d={a1:b1,a2:b2,a3:b3,a4:b4}
if b1>=b2 and b1>=b3 and b1>=b4:
    print("highest marks",a1)
elif b2>=b1 and b2>=b3 and b2>=b4:
    print("highest marks",a2)
elif b3>=b1 and b3>=b2 and b3>=b4:
    print("highest marks",a3)
elif b4>=b1 and b4>=b2 and b4>=b3:
    print("highest marks",a4)
# Out:
# sam
# 89
# manu
# 80
# sony
# 75
# janu
# 99
# highest marks janu

# %%
a={"name":"aman","age":21,"city":"mumbai"}
print(a)
b=a.copy()
print(b)
a.clear()
print(a)
b.update({"country":"india"})
print(b)
# Out:
# {'name': 'aman', 'age': 21, 'city': 'mumbai'}
# {'name': 'aman', 'age': 21, 'city': 'mumbai'}
# {}
# {'name': 'aman', 'age': 21, 'city': 'mumbai', 'country': 'india'}

# %%
data=(10,20,30,20,40,20,50)
d={}
d[10]=data.count(10)
d[20]=data.count(20)
d[30]=data.count(30)
d[40]=data.count(40)
d[50]=data.count(50)
print(d)
# Out:
# {10: 1, 20: 3, 30: 1, 40: 1, 50: 1}

# %% [markdown]
# # Day7(Sets and If Statements)

# %%
sets={1,2,3,4,1}
print(sets)
# Out:
# {1, 2, 3, 4}

# %%
a1=set()
a1.add(1)
a1.add(2)
a1.add(3)
print(a1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 a1=set()
#       2 a1.add(1)
#       3 a1.add(2)
#
# TypeError: 'tuple' object is not callable

# %%
s={10,20,30}
s.update([40,50,60])
print(s)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
a1=sets()
a1.add(1)
a1.add(2)
a1.add(3)
print(a1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 a1=sets()
#       2 a1.add(1)
#       3 a1.add(2)
#
# TypeError: 'dict' object is not callable

# %%
12
# Out:
# 12

# %%
a="varshini"
a
# Out:
# 'varshini'
